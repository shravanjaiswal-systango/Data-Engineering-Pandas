# %% [markdown]
# ## Pandas Workbook

# %% [markdown]
# 1. Creating a table and loading data using Dataframe

# %%
import pandas as pd

data = {
    "name": ["Sumit", "Rahul", "Ankit"],
    "age": [25, 30, 35],
    "salary": [25000, 30000, 35000],
}

df = pd.DataFrame(data)
df
# Out:
#     name  age  salary
# 0  Sumit   25   25000
# 1  Rahul   30   30000
# 2  Ankit   35   35000

# %% [markdown]
# 2. Loading existing data using Dataframe

# %%
df = pd.read_csv('orders.csv')
df
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 1   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 2   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045
# 3   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 4   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 5   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 6   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 7   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 8   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 9   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 10  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 11  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# ...

# %%
# By default, gives first 5 rows
df.head()
df.tail()
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 45  CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715
# 46  CA-2018-146703  20-10-2018  25-10-2018    Second Class    PO-18865
# 47  CA-2020-169194  20-06-2020  25-06-2020  Standard Class    LH-16900
# 48  CA-2020-169194  20-06-2020  25-06-2020  Standard Class    LH-16900
# 49  CA-2019-115742  18-04-2019  22-04-2019  Standard Class    DP-13000
#
#      region       product_id         category  sales  quantity  profit
# 45  Central  OFF-BI-10003291  Office Supplies   17.5         2     8.2
# 46  Central  OFF-ST-10001713  Office Supplies  212.0         4     8.5
# 47     East  TEC-AC-10002167       Technology   45.0         3     5.0
# 48     East  TEC-PH-10003988       Technology   21.8         2     6.1
# 49  Central  OFF-BI-10004410  Office Supplies   38.2         6    18.0

# %% [markdown]
# 3. Checking Datatype of table

# %%
df.dtypes
# By default, pandas reads string, dates as object type
# We need to convert order_date to datetime
# df{'order_date'} = pd.to_datetime(df['order_date'])
# Out:
# order_id        object
# order_date      object
# ship_date       object
# ship_mode       object
# customer_id     object
# region          object
# product_id      object
# category        object
# sales          float64
# quantity         int64
# profit         float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   order_id     50 non-null     object
#  1   order_date   50 non-null     object
#  2   ship_date    50 non-null     object
#  3   ship_mode    50 non-null     object
#  4   customer_id  50 non-null     object
#  5   region       50 non-null     object
#  6   product_id   50 non-null     object
#  7   category     50 non-null     object
#  8   sales        50 non-null     float64
#  9   quantity     50 non-null     int64
#  10  profit       50 non-null     float64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 4.4+ KB

# %% [markdown]
# - df.head() - First 5 rows
# - df.tail() - Last 5 rows
# - df.shape - (rows, columns)
# - df.columns - List of column names
# - df.info() - Data type and null
# - df.describe() - Summary stats for numeric columns
# - df.dtypes - Datatypes

# %%
df.describe()
# Out:
#              sales   quantity       profit
# count    50.000000  50.000000    50.000000
# mean    300.792000   3.920000   -20.550000
# std     547.564035   1.977836   251.767027
# min       2.500000   2.000000 -1665.100000
# 25%      20.075000   2.000000     2.500000
# 50%      74.650000   3.000000     8.350000
# 75%     249.875000   5.000000    17.650000
# max    3083.400000   9.000000   240.300000

# %% [markdown]
# 4. Manipulating column names
# - df.describe
# - df.rename

# %%
df.columns  = ['order_date', 'order_id', 'ship_date', 'ship_mode', 'customer_key',
       'region', 'product_id', 'category', 'sales', 'quantity', 'profit']

# %%
df = pd.read_csv('orders.csv')
#df = pd.read_csv('orders.csv', header=None)
df.columns  = ['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_id',
       'region', 'product_id', 'category', 'sales', 'quantity', 'profit']
df
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 1   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 2   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045
# 3   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 4   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 5   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 6   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 7   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 8   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 9   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 10  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 11  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# ...

# %%
#col = ['order_id','order_date','ship_date']
df_new = df['order_id']

# %% [markdown]
# 5. Dataframe with a single column = Series

# %%
type(df_new)
# Out:
# pandas.core.series.Series

# %% [markdown]
# 6. Selecting rows in range using iloc (index location) and loc (location)

# %%
df.iloc[[2,5,8] , [2,4,6]]
#iloc takes index position of both rows and columns 0:10 give 10 rows
#loc takes index value and column names as well 0:10 give 11 rows
# Out:
#     ship_date customer_id       product_id
# 2  16-06-2020    DV-13045  OFF-LA-10000240
# 5  14-06-2018    BH-11710  FUR-FU-10001487
# 8  14-06-2018    BH-11710  OFF-BI-10003910

# %%
df_new = df.loc[0:10 ,['order_id','order_date','sales']]

# %% [markdown]
# 7. By default index can be changed from 0,1,2,3... to some other column using set index. It doesn't change anything unless given inplace = true

# %%
df.set_index('order_id' , inplace=True)

# %%
df.loc['CA-2020-152156' , 'order_date':'customer_id']
#df.iloc['CA-2019-117415' , 0:2] iloc only takes index
# Out:
#                 order_date   ship_date     ship_mode customer_id
# order_id
# CA-2020-152156  08-11-2020  11-11-2020  Second Class    CG-12520
# CA-2020-152156  08-11-2020  11-11-2020  Second Class    CG-12520

# %%
df.loc[['CA-2021-107727','CA-2020-117590'],['ship_date','order_date']]
# Out:
#                  ship_date  order_date
# order_id
# CA-2021-107727  23-10-2021  19-10-2021
# CA-2020-117590  10-12-2020  08-12-2020
# CA-2020-117590  10-12-2020  08-12-2020

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 1   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 2   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045
# 3   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 4   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 5   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 6   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 7   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 8   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 9   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 10  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 11  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# ...

# %% [markdown]
# 8. Understanding sorting
# - sorting based on index
# - sorting based on column value
#
# by default sorting is in ascending order

# %%
df.sort_index(ascending=True , inplace=True)

# %%
df
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 1   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 2   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045
# 3   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 4   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 5   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 6   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 7   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 8   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 9   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 10  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 11  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# ...

# %%
#multi column sorting is done to do tie breaking
df.sort_values(['quantity','profit'] , ascending=[True,False] , inplace=True )

# %%
#by default reset index makes a new column with old index values
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 1   CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715
# 2   CA-2018-167164  13-05-2018  15-05-2018    Second Class    AG-10270
# 3   CA-2021-139619  19-09-2021  23-09-2021  Standard Class    ES-14080
# 4   CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715
# 5   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045
# 6   CA-2020-169194  20-06-2020  25-06-2020  Standard Class    LH-16900
# 7   CA-2020-121755  16-01-2020  20-01-2020    Second Class    EH-13945
# 8   CA-2020-101343  17-07-2020  22-07-2020  Standard Class    RA-19885
# 9   US-2019-150630  17-09-2019  21-09-2019  Standard Class    TB-21520
# 10  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 11  CA-2018-143336  27-08-2018  01-09-2018    Second Class    ZD-21925
# ...

# %% [markdown]
# 9. Data Filteration

# %%
fc = df['region']=='South' #returns a boolean series
df.loc[fc,]#['order_id']] # first filter(fc) then [#select column]
# another way to filter is-
# df[(df['region']=='South')]
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id region  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 3   CA-2021-139619  19-09-2021  23-09-2021  Standard Class    ES-14080  South
# 10  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
# 16  CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520  South
# 23  CA-2021-114412  15-04-2021  20-04-2021  Standard Class    AA-10480  South
# 37  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335  South
#
#          product_id         category  sales  quantity  profit
# 0   FUR-BO-10001798        Furniture  262.0         2    41.9
# 3   OFF-ST-10003282  Office Supplies   95.6         2     9.6
# 10  OFF-ST-10000760  Office Supplies   22.4         2     2.5
# 16  FUR-CH-10000454        Furniture  731.9         3   219.6
# 23  OFF-PA-10002365  Office Supplies   15.6         3     5.4
# ...

# %% [markdown]
# 10. Multi condition filtering

# %%
#wrap conditions in paranthesis when using multiple conditions and use & for and and | for or
df.loc[(df['region']=='South') & (df['profit']>0)]
df.loc[(df['region']=='South') | (df['profit']>0)]
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 1   CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715
# 2   CA-2018-167164  13-05-2018  15-05-2018    Second Class    AG-10270
# 3   CA-2021-139619  19-09-2021  23-09-2021  Standard Class    ES-14080
# 4   CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715
# 5   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045
# 6   CA-2020-169194  20-06-2020  25-06-2020  Standard Class    LH-16900
# 7   CA-2020-121755  16-01-2020  20-01-2020    Second Class    EH-13945
# 8   CA-2020-101343  17-07-2020  22-07-2020  Standard Class    RA-19885
# 9   US-2019-150630  17-09-2019  21-09-2019  Standard Class    TB-21520
# 10  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 11  CA-2018-143336  27-08-2018  01-09-2018    Second Class    ZD-21925
# ...

# %% [markdown]
# 11. Inverse Filtering

# %%
# use ~ to negate a condition
df[~(df['region']=='South')]
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 1   CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715
# 2   CA-2018-167164  13-05-2018  15-05-2018    Second Class    AG-10270
# 4   CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715
# 5   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045
# 6   CA-2020-169194  20-06-2020  25-06-2020  Standard Class    LH-16900
# 7   CA-2020-121755  16-01-2020  20-01-2020    Second Class    EH-13945
# 8   CA-2020-101343  17-07-2020  22-07-2020  Standard Class    RA-19885
# 9   US-2019-150630  17-09-2019  21-09-2019  Standard Class    TB-21520
# 11  CA-2018-143336  27-08-2018  01-09-2018    Second Class    ZD-21925
# 12  US-2019-150630  17-09-2019  21-09-2019  Standard Class    TB-21520
# 13  US-2021-156909  16-07-2021  18-07-2021    Second Class    SF-20065
# 14  US-2019-150630  17-09-2019  21-09-2019  Standard Class    TB-21520
# ...

# %% [markdown]
# 12. Adding, Updating and Deleting Columns

# %%
df['country'] = 'India'

# %%
df['country'] = 'USA'
df
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 1   CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715
# 2   CA-2018-167164  13-05-2018  15-05-2018    Second Class    AG-10270
# 3   CA-2021-139619  19-09-2021  23-09-2021  Standard Class    ES-14080
# 4   CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715
# 5   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045
# 6   CA-2020-169194  20-06-2020  25-06-2020  Standard Class    LH-16900
# 7   CA-2020-121755  16-01-2020  20-01-2020    Second Class    EH-13945
# 8   CA-2020-101343  17-07-2020  22-07-2020  Standard Class    RA-19885
# 9   US-2019-150630  17-09-2019  21-09-2019  Standard Class    TB-21520
# 10  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 11  CA-2018-143336  27-08-2018  01-09-2018    Second Class    ZD-21925
# ...

# %%
df.drop(columns='country', inplace=True)
df
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 1   CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715
# 2   CA-2018-167164  13-05-2018  15-05-2018    Second Class    AG-10270
# 3   CA-2021-139619  19-09-2021  23-09-2021  Standard Class    ES-14080
# 4   CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715
# 5   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045
# 6   CA-2020-169194  20-06-2020  25-06-2020  Standard Class    LH-16900
# 7   CA-2020-121755  16-01-2020  20-01-2020    Second Class    EH-13945
# 8   CA-2020-101343  17-07-2020  22-07-2020  Standard Class    RA-19885
# 9   US-2019-150630  17-09-2019  21-09-2019  Standard Class    TB-21520
# 10  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 11  CA-2018-143336  27-08-2018  01-09-2018    Second Class    ZD-21925
# ...

# %%
df['profit_flag'] = 1

# %%
df.loc[df['profit']<=0 , 'profit_flag'] = 0

# %% [markdown]
# 13. Multi Condition Grouping

# %%
df['profit_range']='loss'
# Condition 1: Profit < 0
df.loc[df['profit'] < 0, 'profit_range'] = 'loss'

# Condition 2: 0 < Profit < 50 (Must use & and separate parentheses)
df.loc[(df['profit'] > 0) & (df['profit'] < 50), 'profit_range'] = 'low profit'

# Condition 3: Profit > 50
df.loc[df['profit'] > 50, 'profit_range'] = 'high profit'  
df
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 1   CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715
# 2   CA-2018-167164  13-05-2018  15-05-2018    Second Class    AG-10270
# 3   CA-2021-139619  19-09-2021  23-09-2021  Standard Class    ES-14080
# 4   CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715
# 5   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045
# 6   CA-2020-169194  20-06-2020  25-06-2020  Standard Class    LH-16900
# 7   CA-2020-121755  16-01-2020  20-01-2020    Second Class    EH-13945
# 8   CA-2020-101343  17-07-2020  22-07-2020  Standard Class    RA-19885
# 9   US-2019-150630  17-09-2019  21-09-2019  Standard Class    TB-21520
# 10  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 11  CA-2018-143336  27-08-2018  01-09-2018    Second Class    ZD-21925
# ...

# %%
df.drop(columns=['profit_flag','profit_range'], inplace=True)
df
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 1   CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715
# 2   CA-2018-167164  13-05-2018  15-05-2018    Second Class    AG-10270
# 3   CA-2021-139619  19-09-2021  23-09-2021  Standard Class    ES-14080
# 4   CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715
# 5   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045
# 6   CA-2020-169194  20-06-2020  25-06-2020  Standard Class    LH-16900
# 7   CA-2020-121755  16-01-2020  20-01-2020    Second Class    EH-13945
# 8   CA-2020-101343  17-07-2020  22-07-2020  Standard Class    RA-19885
# 9   US-2019-150630  17-09-2019  21-09-2019  Standard Class    TB-21520
# 10  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 11  CA-2018-143336  27-08-2018  01-09-2018    Second Class    ZD-21925
# ...

# %%
df['category_len'] = df['category'].apply(len)

# %% [markdown]
# 14. Applying complex transformations by defining functions

# %%
def profit_loss(profit):
    if profit>0:
        return "profit"
    else:
        return "loss"
df['profit_loss'] = df['profit'].apply(profit_loss)

# %%
df
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 1   CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715
# 2   CA-2018-167164  13-05-2018  15-05-2018    Second Class    AG-10270
# 3   CA-2021-139619  19-09-2021  23-09-2021  Standard Class    ES-14080
# 4   CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715
# 5   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045
# 6   CA-2020-169194  20-06-2020  25-06-2020  Standard Class    LH-16900
# 7   CA-2020-121755  16-01-2020  20-01-2020    Second Class    EH-13945
# 8   CA-2020-101343  17-07-2020  22-07-2020  Standard Class    RA-19885
# 9   US-2019-150630  17-09-2019  21-09-2019  Standard Class    TB-21520
# 10  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 11  CA-2018-143336  27-08-2018  01-09-2018    Second Class    ZD-21925
# ...

# %% [markdown]
# 15. Series Attributes using str methods

# %%
df['category_upper'] = df['category'].str.upper()

# %%
df.drop(columns=['category_upper', 'category_len', 'profit_loss'],inplace=True)

# %%
df
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 1   CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715
# 2   CA-2018-167164  13-05-2018  15-05-2018    Second Class    AG-10270
# 3   CA-2021-139619  19-09-2021  23-09-2021  Standard Class    ES-14080
# 4   CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715
# 5   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045
# 6   CA-2020-169194  20-06-2020  25-06-2020  Standard Class    LH-16900
# 7   CA-2020-121755  16-01-2020  20-01-2020    Second Class    EH-13945
# 8   CA-2020-101343  17-07-2020  22-07-2020  Standard Class    RA-19885
# 9   US-2019-150630  17-09-2019  21-09-2019  Standard Class    TB-21520
# 10  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 11  CA-2018-143336  27-08-2018  01-09-2018    Second Class    ZD-21925
# ...

# %% [markdown]
# 16. Handling missing values and duplicates
# - df.isnull() - missing values
# - df.isnull().sum() - sum of missing values column wise
# - df.info() - total entries, not null values and Dtype

# %%
df.isnull().sum()
# Out:
# order_id       0
# order_date     0
# ship_date      0
# ship_mode      0
# customer_id    0
# region         0
# product_id     0
# category       0
# sales          0
# quantity       0
# profit         0
# dtype: int64

# %%
#Drop na values and hyperparameters
df.dropna()
df.dropna(inplace=True)
df.dropna(subset=['profit'], inplace=True)
df
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 1   CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715
# 2   CA-2018-167164  13-05-2018  15-05-2018    Second Class    AG-10270
# 3   CA-2021-139619  19-09-2021  23-09-2021  Standard Class    ES-14080
# 4   CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715
# 5   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045
# 6   CA-2020-169194  20-06-2020  25-06-2020  Standard Class    LH-16900
# 7   CA-2020-121755  16-01-2020  20-01-2020    Second Class    EH-13945
# 8   CA-2020-101343  17-07-2020  22-07-2020  Standard Class    RA-19885
# 9   US-2019-150630  17-09-2019  21-09-2019  Standard Class    TB-21520
# 10  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 11  CA-2018-143336  27-08-2018  01-09-2018    Second Class    ZD-21925
# ...

# %%
df.fillna("Unknown", inplace=True)

# %%
df
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 1   CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715
# 2   CA-2018-167164  13-05-2018  15-05-2018    Second Class    AG-10270
# 3   CA-2021-139619  19-09-2021  23-09-2021  Standard Class    ES-14080
# 4   CA-2020-118255  11-03-2020  13-03-2020     First Class    ON-18715
# 5   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045
# 6   CA-2020-169194  20-06-2020  25-06-2020  Standard Class    LH-16900
# 7   CA-2020-121755  16-01-2020  20-01-2020    Second Class    EH-13945
# 8   CA-2020-101343  17-07-2020  22-07-2020  Standard Class    RA-19885
# 9   US-2019-150630  17-09-2019  21-09-2019  Standard Class    TB-21520
# 10  US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 11  CA-2018-143336  27-08-2018  01-09-2018    Second Class    ZD-21925
# ...

# %%
data = {
    "name": ["Sumit", "Rahul", "Ankit", "Ankit" , "Ankit"],
    "age": [25, 30, 30 , 30 , 30],
    "salary": [25000, 30000, 35000, 35000 , 35000],
}

df = pd.DataFrame(data)
df
# Out:
#     name  age  salary
# 0  Sumit   25   25000
# 1  Rahul   30   30000
# 2  Ankit   30   35000
# 3  Ankit   30   35000
# 4  Ankit   30   35000

# %%
#drop duplicates based on all columns
df.drop_duplicates()
#drop duplicates based on all columns and keep first occurrence
df.drop_duplicates(keep='first')
#drop duplicates based on all columns and keep last occurrence
df.drop_duplicates(keep='last')
#first and last occurrence is different when using subset parameter
df.drop_duplicates(subset=['age'], keep='first')
# Out:
#     name  age  salary
# 0  Sumit   25   25000
# 1  Rahul   30   30000

# %%
df
df = pd.read_csv('orders.csv')

# %% [markdown]
# 17. Working with Dates & Times i.e. Data Type conversion

# %%
df["order_date"] = pd.to_datetime(df["order_date"] , format ='%d-%m-%Y')

# %%
df["ship_date"] = pd.to_datetime(df["ship_date"] , format ='%d-%m-%Y')

# %% [markdown]
# - df['order_year'] = df['order_date'].dt.year
# - df['order_month'] = df['order_date'].dt.month
# - df['order_day'] = df['order_date'].dt.days
# - df['order_weekday'] = df['order_date'].dt.day_name()

# %%
df['order_year'] = df['order_date'].dt.year

# %% [markdown]
# 18. Operaions & Data Filteration using datetime

# %%
df[df["order_date"] > "2021-01-01"]
# Out:
#           order_id order_date  ship_date       ship_mode customer_id   region  \
# 12  CA-2021-114412 2021-04-15 2021-04-20  Standard Class    AA-10480    South
# 23  US-2021-156909 2021-07-16 2021-07-18    Second Class    SF-20065     East
# 34  CA-2021-107727 2021-10-19 2021-10-23    Second Class    MA-17560  Central
# 41  CA-2021-120999 2021-09-10 2021-09-15  Standard Class    LC-16930  Central
# 43  CA-2021-139619 2021-09-19 2021-09-23  Standard Class    ES-14080    South
#
#          product_id         category  sales  quantity  profit  order_year
# 12  OFF-PA-10002365  Office Supplies   15.6         3     5.4        2021
# 23  FUR-CH-10002774        Furniture   71.4         2    -1.0        2021
# 34  OFF-PA-10000249  Office Supplies   29.5         3     9.9        2021
# 41  TEC-PH-10004093       Technology  147.2         4    16.6        2021
# 43  OFF-ST-10003282  Office Supplies   95.6         2     9.6        2021

# %%
df["transit_days"] = (df["ship_date"] - df["order_date"]).dt.days
df
# Out:
#           order_id order_date  ship_date       ship_mode customer_id   region  \
# 0   CA-2020-152156 2020-11-08 2020-11-11    Second Class    CG-12520    South
# 1   CA-2020-152156 2020-11-08 2020-11-11    Second Class    CG-12520    South
# 2   CA-2020-138688 2020-06-12 2020-06-16    Second Class    DV-13045     West
# 3   US-2019-108966 2019-10-11 2019-10-18  Standard Class    SO-20335    South
# 4   US-2019-108966 2019-10-11 2019-10-18  Standard Class    SO-20335    South
# 5   CA-2018-115812 2018-06-09 2018-06-14  Standard Class    BH-11710     West
# 6   CA-2018-115812 2018-06-09 2018-06-14  Standard Class    BH-11710     West
# 7   CA-2018-115812 2018-06-09 2018-06-14  Standard Class    BH-11710     West
# 8   CA-2018-115812 2018-06-09 2018-06-14  Standard Class    BH-11710     West
# 9   CA-2018-115812 2018-06-09 2018-06-14  Standard Class    BH-11710     West
# 10  CA-2018-115812 2018-06-09 2018-06-14  Standard Class    BH-11710     West
# ...

# %% [markdown]
# 19. Aggregations
# - .sum() - total
# - .mean() - Average
# - .max() - Highest
# - .min() - Lowest
# - .count() - total non-null
# - .nunique() - total number of unique values
# - .unique() - distinct unique values

# %%
df['category'].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
df
# Out:
#           order_id order_date  ship_date       ship_mode customer_id   region  \
# 0   CA-2020-152156 2020-11-08 2020-11-11    Second Class    CG-12520    South
# 1   CA-2020-152156 2020-11-08 2020-11-11    Second Class    CG-12520    South
# 2   CA-2020-138688 2020-06-12 2020-06-16    Second Class    DV-13045     West
# 3   US-2019-108966 2019-10-11 2019-10-18  Standard Class    SO-20335    South
# 4   US-2019-108966 2019-10-11 2019-10-18  Standard Class    SO-20335    South
# 5   CA-2018-115812 2018-06-09 2018-06-14  Standard Class    BH-11710     West
# 6   CA-2018-115812 2018-06-09 2018-06-14  Standard Class    BH-11710     West
# 7   CA-2018-115812 2018-06-09 2018-06-14  Standard Class    BH-11710     West
# 8   CA-2018-115812 2018-06-09 2018-06-14  Standard Class    BH-11710     West
# 9   CA-2018-115812 2018-06-09 2018-06-14  Standard Class    BH-11710     West
# 10  CA-2018-115812 2018-06-09 2018-06-14  Standard Class    BH-11710     West
# ...

# %%
df.groupby('region')['sales'].sum()
# Out:
# region
# Central    3824.8
# East       3467.7
# South      2085.1
# West       5662.0
# Name: sales, dtype: float64

# %% [markdown]
# 20. Multi aggregation aggregate (using .agg)

# %%
df.groupby("region")["sales"].agg(["min", "max" , "sum"]) #m1
df.groupby("region").agg({'sales':"min", 'profit':"max"}) #m2 pass column name and aggregation function in dictionary
# Out:
#          sales  profit
# region
# Central    2.5   123.5
# East       3.3    15.5
# South     15.6   219.6
# West       7.3   240.3

# %%
df.groupby('category').agg({'sales':'sum','profit':'count'})
# Out:
#                   sales  profit
# category
# Furniture        8965.6      12
# Office Supplies  2222.6      28
# Technology       3851.4      10

# %%
df["category"].value_counts()
# Out:
# category
# Office Supplies    28
# Furniture          12
# Technology         10
# Name: count, dtype: int64

# %% [markdown]
# 21. Pivot Tables

# %%
pd.pivot_table(
    df,
    index="region",
    columns="category",
    values="sales",
    aggfunc="sum",
    fill_value=0
)
# Out:
# category  Furniture  Office Supplies  Technology
# region
# Central       935.4           1227.5      1661.9
# East         3279.0            121.9        66.8
# South        1951.5            133.6         0.0
# West         2799.7            739.6      2122.7

# %% [markdown]
# 22. Applying joins / merge on Dataframe
# - inner - common / intersection
# - left - all data from left table
# - right - all data from right table
# - outer - union
# - cross - each row of 1st table joins with each row of 2nd table

# %%
df_orders = pd.read_csv('orders.csv')
df_returns = pd.read_csv('returns.csv')

# %%
df_orders
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 1   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 2   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045
# 3   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 4   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 5   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 6   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 7   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 8   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 9   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 10  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 11  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# ...

# %%
df_returns
# Out:
#   return_order_id return_reason
# 0  CA-2018-105893   bad quality
# 1  CA-2018-143336    wrong item
# 2  CA-2018-146703    wrong item
# 3  CA-2018-167164         other
# 4  CA-2019-106320   bad quality
# 5  CA-2019-115742         other
# 6  CA-2020-101343   bad quality
# 7  CA-2020-117590    wrong item

# %%
df = pd.merge(left = df_orders , right = df_returns, left_on = 'order_id' , right_on='return_order_id'  , how = 'right' )
df
# can use on only if both dataframes have same column name for join key
# don't use on when method is cross as it creates cartesian product of both dataframes
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 0   CA-2018-105893  11-11-2018  18-11-2018  Standard Class    PK-19075
# 1   CA-2018-143336  27-08-2018  01-09-2018    Second Class    ZD-21925
# 2   CA-2018-143336  27-08-2018  01-09-2018    Second Class    ZD-21925
# 3   CA-2018-143336  27-08-2018  01-09-2018    Second Class    ZD-21925
# 4   CA-2018-146703  20-10-2018  25-10-2018    Second Class    PO-18865
# 5   CA-2018-167164  13-05-2018  15-05-2018    Second Class    AG-10270
# 6   CA-2019-106320  25-09-2019  30-09-2019  Standard Class    EB-13870
# 7   CA-2019-115742  18-04-2019  22-04-2019  Standard Class    DP-13000
# 8   CA-2020-101343  17-07-2020  22-07-2020  Standard Class    RA-19885
# 9   CA-2020-117590  08-12-2020  10-12-2020     First Class    GH-14485
# 10  CA-2020-117590  08-12-2020  10-12-2020     First Class    GH-14485
#
#      region       product_id         category   sales  quantity  profit  \
# ...

# %%
df
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 0   CA-2018-105893  11-11-2018  18-11-2018  Standard Class    PK-19075
# 1   CA-2018-143336  27-08-2018  01-09-2018    Second Class    ZD-21925
# 2   CA-2018-143336  27-08-2018  01-09-2018    Second Class    ZD-21925
# 3   CA-2018-143336  27-08-2018  01-09-2018    Second Class    ZD-21925
# 4   CA-2018-146703  20-10-2018  25-10-2018    Second Class    PO-18865
# 5   CA-2018-167164  13-05-2018  15-05-2018    Second Class    AG-10270
# 6   CA-2019-106320  25-09-2019  30-09-2019  Standard Class    EB-13870
# 7   CA-2019-115742  18-04-2019  22-04-2019  Standard Class    DP-13000
# 8   CA-2020-101343  17-07-2020  22-07-2020  Standard Class    RA-19885
# 9   CA-2020-117590  08-12-2020  10-12-2020     First Class    GH-14485
# 10  CA-2020-117590  08-12-2020  10-12-2020     First Class    GH-14485
#
#      region       product_id         category   sales  quantity  profit  \
# ...

# %% [markdown]
# 23. Understanding concat i.e append rows in DF

# %%
emp1 = {"id":[1,2,3],
      "name":["Ankit","Sumit","Amit"],
      "salary":[100,200,300]}
emp2 = {"id":[4,5,6],
      "name":["Nachiket","Rahul","Vinay"],
      "salary":[400,500,600]}

df1 = pd.DataFrame(emp1)
df2 = pd.DataFrame(emp2)

# %%
df1
# Out:
#    id   name  salary
# 0   1  Ankit     100
# 1   2  Sumit     200
# 2   3   Amit     300

# %%
df2
# Out:
#    id      name  salary
# 0   4  Nachiket     400
# 1   5     Rahul     500
# 2   6     Vinay     600

# %%
# pass dfs in a list to concat and use ignore_index to reset index values
df = pd.concat([df1,df2], ignore_index= True)
df
# Out:
#    id      name  salary
# 0   1     Ankit     100
# 1   2     Sumit     200
# 2   3      Amit     300
# 3   4  Nachiket     400
# 4   5     Rahul     500
# 5   6     Vinay     600

# %% [markdown]
# 24. Writing DF to a file
# - to.csv - writes to csv file
# - to.excel - write to excel file
# - to.json - writes to json file
# - to.parquet - write to apache parquet file

# %%
#index values are not needed so we write index = false to ignore index values.
df.to_csv('full_ordersss.csv', index = False)

# %%
df.to_excel("full_orders.xlsx" , index = False)

# %% [markdown]
# 25. Reading DF from a file
# - read.csv - reads from csv file
# - read.excel - reads from excel file
# - read.json - reads from json file
# - read.parquet - reads from apache parquet file

# %%
df_excel = pd.read_excel("full_orders.xlsx") , #sheet_name='orders1')

# %%
df_excel
# Out:
# (   id      name  salary
#  0   1     Ankit     100
#  1   2     Sumit     200
#  2   3      Amit     300
#  3   4  Nachiket     400
#  4   5     Rahul     500
#  5   6     Vinay     600,)

# %% [markdown]
# 26. Reading data from MySQL

# %%
# mysql
from sqlalchemy import create_engine , text
engine = create_engine("mysql+pymysql://Shravan:Shravan123@127.0.0.1:3306/sql_inventory")
#for different database we need to change the connection string accordingly
#engine = create_engine(f"mssql+pyodbc://@{server}/{database}?driver=ODBC+Driver+17+for+SQL+Server&trusted_connection=yes")

# %%
query = "SELECT * FROM products"
df = pd.read_sql(query, con=engine)
df
# Out:
#   product_id        product_name     category  price
# 0        P03        Laptop Stand  Electronics   75.0
# 1        P04      Gaming Headset  Electronics   60.0
# 2        P02  Bluetooth Keyboard  Electronics   45.0
# 3        P01      Wireless Mouse  Electronics   25.0
# 4        P05      Desk Organizer    Furniture   30.0

# %% [markdown]
# 27. Writing Data to MySQL
# - Replace - drop and recreate
# - Append - add rows to existing
# - fail - error if existing

# %%
df.to_sql(name="orders_copy", con=engine, index=False, if_exists="append")
#df.to_sql(name="orders_copy", con=engine, index=False, if_exists="replace")
#in replace it will drop the table if already exists and create a new one
#in append it will add data to existing table if already exists else create a new one
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1938, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1937     if not evt_handled:
# -> 1938         self.dialect.do_executemany(
#    1939             cursor,
#    1940             str_statement,
#    1941             effective_parameters,
#    1942             context,
#    1943         )
#    1944 elif not effective_parameters and context.no_parameters:
#
# File ~/.local/lib/python3.10/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:197, in MySQLDialect_mysqldb.do_executemany(self, cursor, statement, parameters, context)
#     190 def do_executemany(
#     191     self,
#     192     cursor: DBAPICursor,
#    (...)
#     195     context: Optional[ExecutionContext] = None,
#     196 ) -> None:
# ...

# %%
#every time dropping and creating the table is not efficient, moreover all the permissions and indexes will also be lost
#truncate will remove all data from the table but schema will remain same and all permissions and indexes will also be intact
query = text("truncate table products")
with engine.begin() as conn:
    conn.execute(query)
    conn.commit()

# %% [markdown]
# 28. Mini ETL Project
# - Extracting data from json file

# %%
import json
#creating file object
f =  open('orders_etl.json')
data = json.load(f)
data[0]
# Out:
# {'order_id': 1,
#  'order_date': '2024-01-10',
#  'total_amount': 200.5,
#  'customer': {'customer_id': 101,
#   'name': 'John Doe',
#   'email': 'johndoe@example.com',
#   'address': '123 Main StSpringfield'},
#  'products': [{'product_id': 'P01',
#    'name': 'Wireless Mouse',
#    'category': 'Electronics',
#    'price': 25.0,
#    'quantity': 2},
#   {'product_id': 'P02',
#    'name': 'Bluetooth Keyboard',
#    'category': 'Electronics',
#    'price': 45.0,
#    'quantity': 1}]}

# %% [markdown]
# - transforming data into Dataframe and applying basic pre-processing

# %%
#order table
order_id = []
order_date = []
total_amount = []
quantity = []
#customer table
customer_id = []
#product table
product_id = []
product_name = []
category = []
price=[]
customer_name = []
email =[]
address= []
cust_id =[]

for order in data:
    cust_id.append(order['customer']['customer_id'])
    customer_name.append(order['customer']['name'])
    email.append(order['customer']['email'])
    address.append(order['customer']['address'])
    for product in order['products']:
        order_id.append(order['order_id'])
        order_date.append(order['order_date'])
        customer_id.append(order['customer']['customer_id'])
        total_amount.append(order['total_amount'])
        quantity.append(product['quantity'])
        product_id.append(product['product_id'])
        product_name.append(product['name'])
        category.append(product['category'])
        price.append(product['price'])
        
df_orders = pd.DataFrame({
        'order_id': order_id,
        'order_date': order_date,
        'customer_id': customer_id,
        'total_amount': total_amount,
        'product_id': product_id,
        'quantity': quantity
})        
   
df_products = pd.DataFrame({
        'product_id': product_id,
        'product_name': product_name,
        'category': category,
        'price': price,
}) 

df_customers = pd.DataFrame({
        'customer_id': cust_id,
        'customer_name': customer_name,
        'email': email,
        'address': address,
}) 
df_customers.drop_duplicates(subset='customer_id', keep='last' , inplace=True)
df_products.drop_duplicates(subset='product_id', keep='last' , inplace=True)
df_products
# Out:
#    product_id        product_name     category  price
# 18        P03        Laptop Stand  Electronics   75.0
# 19        P04      Gaming Headset  Electronics   60.0
# 20        P02  Bluetooth Keyboard  Electronics   45.0
# 21        P01      Wireless Mouse  Electronics   25.0
# 22        P05      Desk Organizer    Furniture   30.0

# %% [markdown]
# - loading data to sql connected with MySQL DB

# %%
df_orders.to_sql(name="orders", con=engine, index=False, if_exists="replace")
df_products.to_sql(name="products", con=engine, index=False, if_exists="replace")
df_customers.to_sql(name="customers", con=engine, index=False, if_exists="replace")
# Out:
# 9

# %% [markdown]
# ## End of Notebook
